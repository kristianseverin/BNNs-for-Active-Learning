# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# read the loss data
train_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/train_loss.npy')
test_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/test_loss.npy')
val_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/val_loss.npy')

train_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/train_loss.npy')
test_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/test_loss.npy')
val_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/val_loss.npy')

train_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/train_loss.npy')
test_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/test_loss.npy')
val_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/val_loss.npy')

# %%
# set the color 
colors = sns.color_palette("pastel", 8)

# loop through the colors and assign colors_[i] to the color
for i in range(8):
    exec(f'color_{i} = colors[i]')
    




# plot the loss data
fig, ax = plt.subplots(1, 3, figsize=(16, 10))

fig.suptitle('Loss of Curves from Model Training of the Different models', fontsize=20)


# add an edge around the plot
fig.patch.set_edgecolor('black')
fig.patch.set_linewidth('2')

ax[0].plot(train_loss_simple, label='Training Loss', color=color_2)
ax[0].plot(test_loss_simple, label='Test Loss', color=color_0)
ax[0].plot(val_loss_simple, label='Validation Loss', color=color_3)
ax[0].set_title('Simple Closed Form Model Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend()


ax[1].plot(train_loss_dense, label='Training Loss', color=color_2)
ax[1].plot(val_loss_dense, label='Validation Loss', color=color_3)
ax[1].plot(test_loss_dense, label='Test Loss', color=color_0)
ax[1].set_title('Dense Closed Form Model Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend()

# make x_axis
ax[2].plot(train_loss_BBB, label='training loss', color=color_2)
ax[2].plot(test_loss_BBB, label='test loss', color=color_0)
ax[2].plot(val_loss_BBB, label='validation loss', color=color_3)
ax[2].set_title('Bayes By Backprop Model')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('Loss')
ax[2].legend()

# zoom in on the last 100 epochs
 # zoom = 2

with sns.axes_style("dark"):
    x1, x2, y1, y2 = 230, 260, 8000, 8400
  
    axins = ax[2].inset_axes([0.2, 0.2, 0.3, 0.3]) 
    axins.plot(test_loss_BBB, label='test loss', color=color_0)
    axins.plot(val_loss_BBB, label='validation loss', color=color_3)
    axins.set_xlim(x1, x2)
    axins.set_ylim(y1, y2)
    axins.set_title('Zoomed in')
    axins.set_xlabel('Epoch Zoomed in on 230-260 epochs')
    # ylabel on the right side
    axins.set_ylabel('Loss Zoomed in')

    axins.yaxis.set_label_position("right")
   
    ax[2].indicate_inset_zoom(axins)

    # set axins title
    axins.set_title('Zoomed in on the epochs 230-260')

    
# mark the region corresponding to the inset axes on ax1 and draw lines

plt.tight_layout()

# save the plot
plt.savefig('loss_curves_regression.png')

# %%
# read the true vs predicted data
true_simple = np.load('//Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/true.npy')
pred_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/preds.npy')

true_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/true.npy')
pred_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/preds.npy')

true_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/true.npy')
pred_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/preds.npy')

# %%
# plot the true vs predicted data
fig, ax = plt.subplots(1, 3, figsize=(16, 10))

# give the figure a title
fig.suptitle('True vs Predicted Values for Regression Models', fontsize=20)

# add an edge around the plot
fig.patch.set_edgecolor('black')
fig.patch.set_linewidth('2')

sns.distplot(true_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[0], color=color_0)
sns.distplot(pred_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[0], color=color_3)
ax[0].set_xlabel('Values')
ax[0].set_ylabel('Density')
ax[0].set_title('Simple Closed Form Model')
ax[0].legend()

sns.distplot(true_dense, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[1], color=color_0)
sns.distplot(pred_dense, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[1], color=color_3)
ax[1].set_xlabel('Values')
ax[1].set_ylabel('Density')
ax[1].set_title('Dense Closed Form Model')
ax[1].legend()

sns.distplot(true_BBB, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[2], color=color_0)
sns.distplot(pred_BBB, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[2], color=color_3)
ax[2].set_xlabel('Values')
ax[2].set_ylabel('Density')
ax[2].set_title('Bayes By Backprop Model')
ax[2].legend()

plt.tight_layout()

# save the plot
plt.savefig('true_vs_predicted_regression.png')
# Out:
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# load RMSE data
train_RMSE_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/train_RMSE.npy')
test_RMSE_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/test_RMSE.npy')
val_RMSE_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/val_RMSE.npy')

train_RMSE_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/train_RMSE.npy')
test_RMSE_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/test_RMSE.npy')
val_RMSE_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/val_RMSE.npy')

train_RMSE_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/train_RMSE.npy')
test_RMSE_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/test_RMSE.npy')
val_RMSE_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/val_RMSE.npy')

# %%
# plot RMSE data
fig, ax = plt.subplots(1, 3, figsize=(16, 10))

# give the figure a title
fig.suptitle('RMSE of the different models')

ax[0].plot(train_RMSE_simple, label='Training RMSE', color=color_2)
ax[0].plot(test_RMSE_simple, label='Test RMSE', color=color_0)
ax[0].plot(val_RMSE_simple, label='Validation RMSE', color=color_3)
ax[0].set_title('Simple Model RMSE')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('RMSE')
ax[0].legend()

ax[1].plot(train_RMSE_dense, label='Training RMSE', color=color_2)
ax[1].plot(test_RMSE_dense, label='Test RMSE', color=color_0)
ax[1].plot(val_RMSE_dense, label='Validation RMSE', color=color_3)
ax[1].set_title('Dense Model RMSE')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('RMSE')
ax[1].legend()

ax[2].plot(train_RMSE_BBB, label='Training RMSE', color=color_2)
ax[2].plot(test_RMSE_BBB, label='Test RMSE', color=color_0)
ax[2].plot(val_RMSE_BBB, label='Validation RMSE', color=color_3)
ax[2].set_title('Bayes By Backprop Dense Model RMSE')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('RMSE')
ax[2].legend()

plt.tight_layout()

# save the plot
plt.savefig('RMSE_curves_regression.png')
