# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# read the data
train_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/BBB/train_loss.npy')
test_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/BBB/test_loss.npy')
val_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/BBB/val_loss.npy')

train_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/SimpleClassification/train_loss.npy')
test_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/SimpleClassification/test_loss.npy')
val_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/SimpleClassification/val_loss.npy')

train_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/DenseClassification/train_loss.npy')
test_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/DenseClassification/test_loss.npy')
val_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/DenseClassification/val_loss.npy')

# %%
# set the color 
colors = sns.color_palette("pastel", 8)

# loop through the colors and assign colors_[i] to the color
for i in range(8):
    exec(f'color_{i} = colors[i]')
    




# plot the loss data
fig, ax = plt.subplots(1, 3, figsize=(16, 10))

fig.suptitle('Loss of Curves from Model Training of the Different models', fontsize=20)


# add an edge around the plot
fig.patch.set_edgecolor('black')
fig.patch.set_linewidth('2')

ax[0].plot(train_loss_simple, label='Training Loss', color=color_2)
ax[0].plot(test_loss_simple, label='Test Loss', color=color_0)
ax[0].plot(val_loss_simple, label='Validation Loss', color=color_3)
ax[0].set_title('Simple Closed Form Model Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend()


ax[1].plot(train_loss_dense, label='Training Loss', color=color_2)
ax[1].plot(val_loss_dense, label='Validation Loss', color=color_3)
ax[1].plot(test_loss_dense, label='Test Loss', color=color_0)
ax[1].set_title('Dense Closed Form Model Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')

# manually set the y-ticks
ax[1].set_yticklabels([0, 0.2, 0.4, 0.6, 0.8])

ax[1].legend()



# make x_axis
ax[2].plot(train_loss_BBB, label='training loss', color=color_2)
ax[2].plot(test_loss_BBB, label='test loss', color=color_0)
ax[2].plot(val_loss_BBB, label='validation loss', color=color_3)
ax[2].set_title('Bayes By Backprop Model')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('Loss')
ax[2].legend()


plt.tight_layout()

# save the plot
plt.savefig('loss_curves_classification.png')
# Out:
# <ipython-input-25-f2e78639815c>:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels([0, 0.2, 0.4, 0.6, 0.8])

# %%
train_accuracy_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/SimpleClassification/train_accuracy.npy')
test_accuracy_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/SimpleClassification/test_accuracy.npy')
val_accuracy_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/SimpleClassification/val_accuracy.npy')

train_accuracy_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/DenseClassification/train_accuracy.npy')
test_accuracy_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/DenseClassification/test_accuracy.npy')
val_accuracy_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/DenseClassification/val_accuracy.npy')

train_accuracy_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/BBB/train_accuracy.npy')
test_accuracy_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/BBB/test_accuracy.npy')
val_accuracy_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Classification/BBB/val_accuracy.npy')

# %%
# plot Accuracy data
fig, ax = plt.subplots(1, 3, figsize=(16, 10))

# give the figure a title
fig.suptitle('Accuracy of the different models', fontsize=20)

ax[0].plot(train_accuracy_simple, label='Training Accuracy', color=color_2)
ax[0].plot(test_accuracy_simple, label='Test Accuracy', color=color_0)
ax[0].plot(val_accuracy_simple, label='Validation Accuracy', color=color_3)
ax[0].set_title('Simple Model Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend()

ax[1].plot(train_accuracy_dense, label='Training Accuracy', color=color_2)
ax[1].plot(test_accuracy_dense, label='Test Accuracy', color=color_0)
ax[1].plot(val_accuracy_dense, label='Validation Accuracy', color=color_3)
ax[1].set_title('Dense Model Accuracy')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].legend()

ax[2].plot(train_accuracy_BBB, label='Training Accuracy', color=color_2)
ax[2].plot(test_accuracy_BBB, label='Test Accuracy', color=color_0)
ax[2].plot(val_accuracy_BBB, label='Validation Accuracy', color=color_3)
ax[2].set_title('Bayes By Backprop Dense Model Accuracy')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('Accuracy')
ax[2].legend()

plt.tight_layout()

# save the plot
plt.savefig('accuracy_curves_classification.png')
